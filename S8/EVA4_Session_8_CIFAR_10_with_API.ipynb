# %% [markdown]
# <a href="https://colab.research.google.com/github/siva-sankar-a/eva/blob/master/S8/EVA4_Session_8_CIFAR_10_with_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # S8 _Assignment 8_
#
#   | Summary of overall targets |  |
#   | - | - |
#   | _Dataset_| **CIFAR10** |
#   | _Max. number of epochs_| **NA** |
#   | _Max. number of parameters_| **NA** |
#   | _Architecture_| **Resnet18** |

# %% [markdown]
# # Implementation

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### Mounting google drive to save results

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install torchsummary
# !pip install torchviz
# !pip install receptivefield>=0.5.0
# Out:
# ...
#      |████████████████████████████████| 51kB 4.7MB/s
# ...
#   Created wheel for torchviz: filename=torchviz-0.0.1-cp36-none-any.whl size=3523 sha256=55e3ca16b873207a6ba49ecad229d46b8bd3bc8f946d063dee6002b5a4515038
#   Stored in directory: /root/.cache/pip/wheels/2a/c2/c5/b8b4d0f7992c735f6db5bfa3c5f354cf36502037ca2b585667
# Successfully built torchviz
# ...

# %%
import glob
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# !rm -rf eva
# !git clone "https://github.com/siva-sankar-a/eva.git"
# Out:
# Cloning into 'eva'...
# remote: Enumerating objects: 266, done.
# remote: Counting objects: 100% (266/266), done.
# remote: Compressing objects: 100% (204/204), done.
# remote: Total 266 (delta 138), reused 142 (delta 55), pack-reused 0
# Receiving objects: 100% (266/266), 4.42 MiB | 7.94 MiB/s, done.
# Resolving deltas: 100% (138/138), done.

# %%
# %load_ext autoreload
# %autoreload 2
from eva.S8.api import Experiment
from eva.S8.viz import viz_cifar10_grid
from eva.S8.utils import textual_summary_cifar10, graphical_summary_cifar10

# %% [markdown]
# ### Create an instance of experiment class

# %%
cifar10_experiment = Experiment(name=f'default', dataset_name='cifar10')
# Out:
# CUDA status: True
# ...
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
viz_cifar10_grid(cifar10_experiment.data_manager.train_loader)
# Out:
#   cat   car  deer horse

# %%
textual_summary_cifar10(cifar10_experiment.model)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
# ...

# %%
graphical_summary_cifar10(cifar10_experiment.model)

# %%
cifar10_experiment.run(epochs=25, momentum=0.9, lr=0.01, regularization=None, weight_decay=0.01)
# Out:
# TRAIN : epoch=0 train_loss=0.02305 correct/total=23265/50000 accuracy=46.53: 100%|██████████| 782/782 [00:58<00:00, 13.30it/s]
# TEST :  epoch=0 test_loss=1.21728 correct/total=5893/10000 accuracy=58.93: 100%|██████████| 157/157 [00:04<00:00, 40.01it/s]
# TRAIN : epoch=1 train_loss=0.01575 correct/total=32261/50000 accuracy=64.52: 100%|██████████| 782/782 [00:59<00:00, 13.21it/s]
# TEST :  epoch=1 test_loss=0.92927 correct/total=6837/10000 accuracy=68.37: 100%|██████████| 157/157 [00:04<00:00, 38.09it/s]
# TRAIN : epoch=2 train_loss=0.01263 correct/total=35918/50000 accuracy=71.84: 100%|██████████| 782/782 [00:59<00:00, 13.07it/s]
# TEST :  epoch=2 test_loss=0.75612 correct/total=7459/10000 accuracy=74.59: 100%|██████████| 157/157 [00:04<00:00, 39.92it/s]
# TRAIN : epoch=3 train_loss=0.01089 correct/total=37819/50000 accuracy=75.64: 100%|██████████| 782/782 [00:59<00:00, 13.04it/s]
# ...

# %% [markdown]
# # Result
# | Metric | Value |
# | - | - |
# | _Best train accuracy_| **94.71** |
# | _Best test accuracy_| **90.76** |
# | _Best epoch number_| **21** |
# | _Parameter count_ | **11,173,962** |
